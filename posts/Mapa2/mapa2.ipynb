# %% [raw]
# ---
# title: "folium points"
# author: "Marco Aguirre"
# date: "2025-10-27"
# categories: [dataviz, code, folium]
# image: "img.png"
# toc: true
# embed-resources: true
# ---

# %%
import pandas as pd

# %%
df= pd.read_excel("mapaPatricion.xlsx", skiprows=1)

df.head()
# Out:
#                  b. NOMBRE DEL CENTRO DE FAENAMIENTO      a. X       b. Y  c. Z
# 0  CENTRO DE FAENAMIENTO EMPRESA MUNICIPAL DE SER...  724495.0  9683113.0  2538
# 1  CENTRO DE FAENAMIENTO DEL GAD MUNICIPAL DE GUA...  747612.0  9680341.0  2228
# 2  CENTRO DE FAENAMIENTO DEL GAD MUNICIPAL DEL SI...  721314.0  9662528.0  2788
# 3   CENTRO DE FAENAMIENTO DEL GAD MUNICIPAL DE PAUTE  750021.0  9693269.0  2173
# 4     CENTRO DE FAENAMIENTO DEL GAD MUNICIPAL PUCARÁ  670274.0  9643909.0  3100

# %%
df.columns
# Out:
# Index(['b. NOMBRE DEL CENTRO DE FAENAMIENTO', 'a. X', 'b. Y', 'c. Z'], dtype='object')

# %%
import pandas as pd
from pyproj import Transformer

def infer_zona_utm(x):
    if 166000 <= x <= 833000:
        return 17
    elif 833000 < x <= 1660000:  # No aplica a Ecuador
        return 18
    else:
        return 17  # Valor por defecto

def utm_to_latlon_auto(row):
    zona = infer_zona_utm(row['a. X'])
    epsg_utm = f"EPSG:327{zona}"
    transformer = Transformer.from_crs(epsg_utm, "EPSG:4326", always_xy=True)
    lon, lat = transformer.transform(row['a. X'], row['b. Y'])
    return pd.Series({'LATITUD': lat, 'LONGITUD': lon, 'ZONA_UTM': zona})

df[['LATITUD', 'LONGITUD', 'ZONA_UTM']] = df.apply(utm_to_latlon_auto, axis=1)

# %%
import folium
import pandas as pd

# Example dataframe


# Create a Folium map centered around Ecuador
m = folium.Map(location=[-2.8, -78.9], zoom_start=8)

# Add markers
for _, row in df.iterrows():
    folium.Marker(
        location=[row['LATITUD'], row['LONGITUD']],
        popup=f"{row['b. NOMBRE DEL CENTRO DE FAENAMIENTO']}<br>Altitud: {row['LONGITUD']} m",
        icon=folium.Icon()
    ).add_to(m)

# Save map
map_path = "mapa_faenamiento.html"
m.save(map_path)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64b3a9b9cea2b0ca449c2c35b8b755f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64b3a9b9cea2b0ca449c2c35b8b755f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64b3a9b9cea2b0ca449c2c35b8b755f7 = L.map(
#                 &quot;map_64b3a9b9cea2b0ca449c2c35b8b755f7&quot;,
#                 {
#                     center: [-2.8, -78.9],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0df740f4d7947d57566ee6c74adc650 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0df740f4d7947d57566ee6c74adc650.addTo(map_64b3a9b9cea2b0ca449c2c35b8b755f7);
#
#
#             var marker_98f2edbb0e48bbfa39345ed62fd1d539 = L.marker(
#                 [-2.865162282534308, -78.98043090748419],
#                 {
# }
#             ).addTo(map_64b3a9b9cea2b0ca449c2c35b8b755f7);
#
#
#             var icon_4150b1dcfdb66191e384e4c5e38f7999 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_98f2edbb0e48bbfa39345ed62fd1d539.setIcon(icon_4150b1dcfdb66191e384e4c5e38f7999);
#
#
#         var popup_8b41783120ce39aa9eb2a8c6569f31ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b5660c1705bcf2db3a5594de3a2347b = $(`&lt;div id=&quot;html_5b5660c1705bcf2db3a5594de3a2347b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CENTRO DE FAENAMIENTO EMPRESA MUNICIPAL DE SERVICIOS DE RASTROS Y PLAZAS DE GANADO DEL CANTÓN CUENCA EMURPLAG EP&lt;br&gt;Altitud: -78.98043090748419 m&lt;/div&gt;`)[0];
#                 popup_8b41783120ce39aa9eb2a8c6569f31ff.setContent(html_5b5660c1705bcf2db3a5594de3a2347b);
#
#
#
#         marker_98f2edbb0e48bbfa39345ed62fd1d539.bindPopup(popup_8b41783120ce39aa9eb2a8c6569f31ff)
#         ;
#
#
#
#
#             var marker_fb45e71b830edd241ab79a5139a85343 = L.marker(
#                 [-2.889834388394234, -78.77252126788711],
#                 {
# }
#             ).addTo(map_64b3a9b9cea2b0ca449c2c35b8b755f7);
#
#
#             var icon_85b4378c5c46f9b736f48766edd3beeb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fb45e71b830edd241ab79a5139a85343.setIcon(icon_85b4378c5c46f9b736f48766edd3beeb);
#
#
#         var popup_96a61f48d6369c50f074e47d568c5077 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15a20e54e984bbfb6df36ccb294fd31d = $(`&lt;div id=&quot;html_15a20e54e984bbfb6df36ccb294fd31d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CENTRO DE FAENAMIENTO DEL GAD MUNICIPAL DE GUALACEO&lt;br&gt;Altitud: -78.77252126788711 m&lt;/div&gt;`)[0];
#                 popup_96a61f48d6369c50f074e47d568c5077.setContent(html_15a20e54e984bbfb6df36ccb294fd31d);
#
#
#
#         marker_fb45e71b830edd241ab79a5139a85343.bindPopup(popup_96a61f48d6369c50f074e47d568c5077)
#         ;
#
#
#
#
#             var marker_26b2e0f69000928b6a085858ebc7e901 = L.marker(
#                 [-3.051333390397727, -79.00870349021385],
#                 {
# }
#             ).addTo(map_64b3a9b9cea2b0ca449c2c35b8b755f7);
#
#
#             var icon_ffca649be0f89fe000b92f529c5dc461 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_26b2e0f69000928b6a085858ebc7e901.setIcon(icon_ffca649be0f89fe000b92f529c5dc461);
#
#
#         var popup_c319ed70e91003c7c56b90b991c2c04c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_764c3924bb9c380d6dc7489e85b50df5 = $(`&lt;div id=&quot;html_764c3924bb9c380d6dc7489e85b50df5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CENTRO DE FAENAMIENTO DEL GAD MUNICIPAL DEL SIGSIG&lt;br&gt;Altitud: -79.00870349021385 m&lt;/div&gt;`)[0];
#                 popup_c319ed70e91003c7c56b90b991c2c04c.setContent(html_764c3924bb9c380d6dc7489e85b50df5);
#
#
#
#         marker_26b2e0f69000928b6a085858ebc7e901.bindPopup(popup_c319ed70e91003c7c56b90b991c2c04c)
#         ;
