# %% [raw]
# ---
# title: "Titulo del Poster"
# author: "Marco Aguirre"
# date: "2025-09-11"
# categories: [Python, Herramientas utilizadas, Plotly , tipo de grafico]
# image: "poster.png"
# toc: true
# jupyter: python3
# ---

# %% [markdown]
# # Contexto
# Describa en 3–5 frases qué pretende mostrar el póster y por qué es relevante. Incluya:
# - Pregunta guía (¿qué quiere responder la visualización?).
# - Audiencia (¿a quién va dirigida?).
# - Decisión/acción esperada (¿qué debería ocurrir después de ver el gráfico?).

# %% [markdown]
# ![poster.png](attachment:poster.png)

# %% [markdown]
# # Dataset
# - Nombre: {{< param dataset_nombre >}}
# - Fuente (link): [Abrir dataset]({{< param dataset_url >}})
#
# # Diseño
#
# Enlace al notebook de las iteraciones: [Abrir notebook]({{</posts/Isotype/missingno.ipynb>}})
#
# [Ver Notebook de Iteraciones](/posts/WordCloud/WordCloud.ipynb)
